# %% [markdown]
# <center>
#     <h1 style="color:blue"> YSU MMF, Python, Spring 2021 </h1>
#     <h2 style="color:blue"> Lecture 25 </h2>
# </center>

# %%
# %config Completer.use_jedi = False

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Matplotlib

# %% [markdown]
# - Plot a 1D vector, and explain

# %%
y = [1,4,5]
x = [0,1,2]
plt.plot(x, y, 'ro--')

# %%
y = [1,4,5]
x = [0,1,2]
plt.plot(x, y, 'r^--', lw= 3)

# %% [markdown]
# - Take 2 1D arrays of the same size, and plot one vs the other. Use `plt.scatter` and `plt.plot`. Explain

# %%
x = np.array([1,2,3,4])
y = np.array([-1,2,-3,4])

# %%
plt.scatter(y,x, s = 150, marker="+")

# %%
plt.plot(y,x)

# %%
from sklearn.datasets import make_blobs, make_classification

# %%
x, y = make_classification(n_classes=3, n_clusters_per_class=1, n_features=2,n_informative=2, n_redundant=0, n_samples=100, )

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
x[:100]
# Out:
# array([[ 0.86089329, -1.29540668],
#        [-1.34159976, -0.40911639],
#        [-0.403964  , -2.00201136],
#        [ 0.82079213, -0.52270704],
#        [ 0.02991797, -1.34600819],
#        [ 0.87257833,  1.85465571],
#        [ 1.93447223, -1.11311584],
#        [-1.48540676, -0.20530552],
#        [-0.53342988, -1.79778266],
#        [ 1.84423664, -0.47363132],
#        [ 1.07121871, -0.7988921 ],
#        [ 1.14407866, -1.29629853],
#        [-0.15173639, -1.4659723 ],
#        [ 0.96122882, -1.27170125],
#        [ 0.90951806,  0.74671541],
#        [-2.22673019,  1.00883326],
#        [ 2.23585746, -0.72772681],
#        [ 1.18006186, -0.88580934],
#        [-1.12493963, -0.77116277],
#        [ 0.95430818, -0.70927028],
#        [ 1.60768922,  0.41315555],
#        [ 1.2215376 , -0.34854683],
#        [-1.52660112, -0.17866249],
#        [ 0.71230424,  0.67873132],
#        [-0.26620657, -2.23673418],
#        [ 3.02537348, -0.81046778],
#        [ 0.88968792,  1.19104588],
#        [-1.64680003,  0.06946947],
#        [-1.51186809, -0.17741763],
#        [-0.57437217, -1.76812131],
#        [-1.51996045, -0.10642992],
#        [-0.49839915, -1.81579037],
#        [ 1.22807078, -0.75053605],
#        [ 0.79211585, -1.22029133],
#        [ 0.50897669,  0.44753273],
#        [ 1.07200009, -0.76012002],
#        [ 1.1369902 ,  1.46434381],
#        [ 0.77581833, -1.26346127],
#        [ 1.13549175,  2.09011456],
#        [ 0.73186158,  0.68630451],
#        [ 0.72731811,  2.36872375],
#        [-0.46863467, -1.46839922],
#        [ 1.4045585 ,  0.26793893],
#        [-0.43752721, -1.96594851],
#        [ 0.39512946,  2.02571778],
#        [-0.64946377, -1.62480644],
#        [ 1.00624065,  1.27381599],
#        [ 1.35201088,  1.06685701],
#        [-1.57480444, -0.06542609],
#        [ 1.23836914,  1.67426753],
#        [ 1.2829811 , -1.07275692],
#        [-0.20727232, -1.53215216],
#        [ 1.06517825, -0.16025075],
#        [ 0.16158708, -1.30697667],
#        [-0.48426922, -1.85153312],
#        [ 0.98666189,  1.16666649],
#        [ 0.32275787, -1.63695713],
#        [ 1.625497  , -0.91990906],
#        [ 0.75834186,  1.07725718],
#        [-1.61698965,  0.02795626],
#        [ 0.78449875, -1.69394363],
#        [-1.80078127,  0.32045458],
#        [ 1.06145663,  1.10228981],
#        [ 2.43949472, -0.68575931],
#        [ 0.70009901,  1.18407795],
#        [ 1.31041994, -1.02787739],
#        [ 1.70928001, -0.32285325],
#        [ 1.4051224 , -1.22449153],
#        [-0.02737698, -2.64697467],
#        [-0.09574183, -0.80055687],
#        [ 0.03430965, -2.73376363],
#        [-1.06049509, -0.93125386],
#        [ 1.15708621,  0.97922643],
#        [ 0.08519338, -1.12714607],
#        [-0.94966968, -1.09085627],
#        [-1.08495073, -0.86100706],
#        [ 0.86678945, -1.33014675],
#        [ 0.50215121,  2.6334213 ],
#        [ 0.71726664,  1.79240728],
#        [ 0.77011192, -0.54118679],
#        [-1.89983792,  0.52698147],
#        [-0.90588929, -1.11764808],
#        [-0.00833972, -2.6818304 ],
#        [-0.63269529, -1.60142539],
#        [ 1.19030088, -1.22444427],
#        [-0.49521193, -1.86521077],
#        [ 0.92311911,  0.12658864],
#        [ 0.9723213 ,  0.63650766],
#        [-0.87122821, -1.2469424 ],
#        [ 1.27625866, -0.94320608],
#        [ 1.09293779,  1.41102028],
#        [-0.94791802, -1.14066287],
#        [ 0.77431718,  1.39582448],
#        [ 1.06160447,  1.44673365],
#        [ 1.53606921, -0.736145  ],
#        [ 0.81802692,  1.29188042],
#        [-1.05581689, -0.90720675],
#        [ 1.19679925,  0.8152711 ],
#        [-1.69201413,  0.12549021],
#        [-1.06252169, -0.88995343]])

# %%
plt.scatter(x[:,0], x[:,1],c = y)

# %% [markdown]
# - Plot a Scatterplot, change the parameters within

# %%
x = np.linspace(0.001,0.1, 500)
y = 0.2*(x**2)*np.sin(1/x)
z = 0.2*(x**2)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, linestyle="--", c= "green")# "g--"
plt.plot(x,z)

# %% [markdown]
# - Load a Classification Dataset from `sklearn`, plot the points with labels as colors

# %% [markdown]
# - Plot the graph of $f(x) = 0.2\cdot x^2\cdot \sin\dfrac{1}{x}$ over $[0.001, 0.1]$. Make it dashed and green

# %% [markdown]
# - Add the graphs of $\pm 0.2\cdot x^2$, in red solid

# %% [markdown]
# - Add the maximum points to the graph, in blue

# %% [markdown]
# - Add a title "The graph of $x^2\sin\dfrac{1}{x}$"

# %% [markdown]
# - Add X and Y axis Labels

# %% [markdown]
# - Add a Legend

# %% [markdown]
# - Make a figure with sizes (7,7), and plot uniform random points in the square $[0,1]\times[0,1]$. Change the aspect ratio

# %% [markdown]
# - Make a figure with 2 subplots. Plot something on each of the subplots

# %% [markdown]
# - For some Distributions, plot the graphs of a PDF, CDF, generate random points, and plot some histogram in subplots. Add a title for each subplot, add some texts to plots

# %% [markdown]
# - Read the `digits` Dataset from `sklearn`, plot the first 25 images in a $5\times 5$ matrix
